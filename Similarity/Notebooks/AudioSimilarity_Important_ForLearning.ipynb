# %%
from transformers import pipeline

# Replace with your actual HF repo path (e.g., "anujbohra/whisper-marathi-finetuned")
asr_pipeline = pipeline(
    "automatic-speech-recognition",
    model="bohraanuj23/whisper-small-hindi",
    device=0  # set to -1 for CPU
)
# Out:
# config.json:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/967M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.86k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.19k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/339 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
# audio path from earlier audio extraction
transcription = asr_pipeline("HindiAudioSample.mp3")
# Access the text output
print("Transcribed Text:", transcription['text'])
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# Transcribed Text: उसके लिए दैंक्य। कभि लभी आप अपर्ट बेल देते हो, उसके लिए भी दैंक्य। दो मेले-मेले आपने मेरे चप्पल सिला के लेगा ऐशिक, उसके लिए वी दैंक्य। आप मेरे सारी को भी स्थनी कर देते हो, उसके लिए वी दैंक्य। और यह प्रडो दैंक्य। काय तल रहा पात्वीए? मैंने अपको जाए दी तो अपने मुझे दैंक्यो पोला पाता... तो मेरे तो कित नी दैंक्यो पोल पके... इसलिए अभी पोल रहीं... तैंक्य। सोरी...

# %%
import torch
from transformers import WhisperProcessor, WhisperForConditionalGeneration
import torchaudio

# Load processor and model
processor = WhisperProcessor.from_pretrained("bohraanuj23/whisper-small-hindi")
model = WhisperForConditionalGeneration.from_pretrained("bohraanuj23/whisper-small-hindi").to("cuda")

# Load long audio
speech_array, sampling_rate = torchaudio.load("/content/tmkoc.mp3")
speech_array = torchaudio.functional.resample(speech_array, orig_freq=sampling_rate, new_freq=16000).squeeze()

# Parameters
chunk_length_s = 30  # seconds
stride_length_s = 5  # seconds overlap for context
input_stride = stride_length_s * 16000
input_chunk = chunk_length_s * 16000

# Store text
full_transcript = ""

# Process in chunks
start = 0
while start < len(speech_array):
    end = min(start + input_chunk, len(speech_array))
    chunk = speech_array[start:end]

    inputs = processor.feature_extractor(chunk, sampling_rate=16000, return_tensors="pt").input_features.to("cuda")

    with torch.no_grad():
        predicted_ids = model.generate(inputs)
    text = processor.tokenizer.batch_decode(predicted_ids, skip_special_tokens=True)[0]
    full_transcript += " " + text

    start += input_chunk - input_stride  # move window with overlap

print(full_transcript)
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
#  उसके लिए थैंक्य। कभी-कभी आप अपर्ट बेल देते हो, उसके लिए भी थैंक्य। दो मेले-मेले आपने मेरे चप्पल सिला के लेगा ऐ थे, उसके लिए वी थैंक्य। आप मेरे सारी को भी स्थनी कर देते हो, उसके लिए वी थैंक्य। और यह पुर्ड, थैंक्य। काई तलग रहे पात्वी है? मैंने अपको चाय दी तो अपने मुझे थैंक्यो पोला पाता, तो मेरे तो कित... नी तो तो तो पुल पाके। इसलिया अभी पोल रही हो, तैंक्य। सड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ फॉरीःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःःः अप्रटर हाथी कभी आ गया वरी गोड़ शेवर का भी आ गया जेटाला...ः इस आति का मेंटिनस का चे कभी भी ताइपड़ नहीं आता देगालो फोंग करा उठवर गरा

# %%
# !pip install faster-whisper jiwer
# Out:
# Collecting faster-whisper
#   Downloading faster_whisper-1.1.1-py3-none-any.whl.metadata (16 kB)
# Collecting jiwer
#   Downloading jiwer-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting ctranslate2<5,>=4.0 (from faster-whisper)
#   Downloading ctranslate2-4.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub>=0.13 in /usr/local/lib/python3.11/dist-packages (from faster-whisper) (0.32.4)
# Requirement already satisfied: tokenizers<1,>=0.13 in /usr/local/lib/python3.11/dist-packages (from faster-whisper) (0.21.1)
# Collecting onnxruntime<2,>=1.14 (from faster-whisper)
#   Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting av>=11 (from faster-whisper)
#   Downloading av-14.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from faster-whisper) (4.67.1)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.11/dist-packages (from jiwer) (8.2.1)
# Collecting rapidfuzz>=3.9.7 (from jiwer)
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (2.0.2)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.11/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper) (1.1.2)
# Collecting coloredlogs (from onnxruntime<2,>=1.14->faster-whisper)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (1.13.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper) (1.3.0)
# Downloading faster_whisper-1.1.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.7 MB/s eta 0:00:00
# Downloading jiwer-3.1.0-py3-none-any.whl (22 kB)
# Downloading av-14.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 27.0 MB/s eta 0:00:00
# Downloading ctranslate2-4.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 15.9 MB/s eta 0:00:00
# Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 75.6 MB/s eta 0:00:00
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 53.7 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.5 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, humanfriendly, ctranslate2, av, jiwer, coloredlogs, onnxruntime, faster-whisper
# Successfully installed av-14.4.0 coloredlogs-15.0.1 ctranslate2-4.6.0 faster-whisper-1.1.1 humanfriendly-10.0 jiwer-3.1.0 onnxruntime-1.22.0 rapidfuzz-3.13.0

# %%
from faster_whisper import WhisperModel
import jiwer

# Initialize Whisper model
model_size = "large-v3"
model = WhisperModel(model_size, device="cuda", compute_type="float16")

# Transcribe audio
segments, info = model.transcribe("/content/ted_60.wav", beam_size=5)

# Display detected language
print("Detected language '%s' with probability %f" % (info.language, info.language_probability))

# Extract transcribed text
transcribed_text = " ".join([segment.text for segment in segments])

# Ground truth (replace this with actual correct transcript)
ground_truth = """
So in college, I was a government major, which means I had to write a lot of papers. Now, when a normal student writes a paper, they might spread the work out a little like this. So you know.
You get started maybe a little slowly, but you get enough done in the first week that with some heavier days later on, everything gets done and things stay civil. And I would want to do that, like that. That would be the plan. I would have it all ready to go, but then actually the paper would come along, and then I would kind of do this.
And that would happen to every single paper. But then came my 90-page senior thesis, a paper you're supposed to spend a year on. I knew for a paper like that, my normal workflow was not an option, it was way too big a project. So I planned things out, and I decided it kind of had to go something like this. This is how the year would go. So I'd start off light, and I'd bump it up.
"""

# Calculate WER
wer = jiwer.wer(ground_truth, transcribed_text)

print("\nTranscribed Text:\n", transcribed_text)
print("\nWord Error Rate (WER):", wer)
# Out:
# Detected language 'en' with probability 0.997559
#
# Transcribed Text:
#   So in college, I was a government major,  which means I had to write a lot of papers.  Now, when a normal student writes a paper,  they might spread the work out a little like this.  So, you know, you get started maybe a little slowly,  but you get enough done in the first week  that with some heavier days later on,  everything gets done and things stay civil.  And I would want to do that like that.  That would be the plan.  I would have it all ready to go,  but then actually the paper would come along,  and then I would kind of do this.  And that would happen to every single paper.  But then came my 90-page senior thesis,  a paper you're supposed to spend a year on.  And I knew for a paper like that,  my normal workflow was not an option.  It was way too big a project.  So I planned things out, and I decided  I kind of had to go something like this.  This is how the year would go.  So I'd start off light,  and I'd bump it up.
#
# Word Error Rate (WER): 0.05434782608695652

# %%
from faster_whisper import WhisperModel

model_size = "large-v3"

# Run on GPU with FP16
model = WhisperModel(model_size, device="cuda", compute_type="float16")

# or run on GPU with INT8
# model = WhisperModel(model_size, device="cuda", compute_type="int8_float16")
# or run on CPU with INT8
# model = WhisperModel(model_size, device="cpu", compute_type="int8")

segments, info = model.transcribe("/content/tmkoc.mp3", beam_size=5)

print("Detected language '%s' with probability %f" % (info.language, info.language_probability))

for segment in segments:
    print("[%.2fs -> %.2fs] %s" % (segment.start, segment.end, segment.text))
# Out:
# Detected language 'hi' with probability 0.771973
# [0.00s -> 1.18s]  उसके लिए थैंक यू
# [1.18s -> 3.06s]  कभी कभी आप पापड मिल देते हो
# [3.06s -> 4.08s]  उसके लिए भी थैंक यू
# [4.08s -> 7.46s]  दो मेले पहले आपने मेरे चप्पल सीला के लेके आए थे
# [7.46s -> 8.44s]  उसके लिए भी थैंक यू
# [8.44s -> 11.08s]  आप मेरी सारी को भी हिस्सी कर देते हो
# [11.08s -> 12.96s]  उसके लिए भी थैंक यू
# [12.96s -> 16.32s]  और एक दिन तो थैंक यू पूरा काई तलने मात भी है
# [16.32s -> 18.76s]  मैंने आपको जब चाय दी तो आपने मुझे थैंक यू बोला था
# [18.76s -> 21.34s]  तो मेरे तो किसने थैंक यू बोलने बाग है
# [21.34s -> 24.70s]  इसलिए अभी बोल रही हूँ थैंक यू
# [24.70s -> 26.28s]  सोरी
# [26.28s -> 30.64s]  परसो चाय में शक्कर जादा हो गई थी उसके लिए सोरी
# [30.64s -> 33.80s]  खादे में नबक जादा हो गई था उसके लिए भी सोरी
# [33.80s -> 36.96s]  और आपके गुर्टे का पटन लगाना भूल गई थी उसके लिए भी सोरी
# [36.96s -> 39.18s]  एक दिन तो थैंक यू पूरा काई तलने मात भी है
# [39.18s -> 42.36s]  आहो पति पति में थैंक यू और सोरी होता ही नहीं है
# [42.36s -> 43.86s]  कर लो
# [43.86s -> 45.18s]  कर लो सोरी
# [45.18s -> 46.20s]  थैंक यू
# [46.20s -> 51.36s]  चाय पीछे बदला खंडी हो जाएगी
# [51.36s -> 58.70s]  प्रॉटर हाथी का भी आ गया है
# [58.70s -> 60.36s]  वेरी विल्ड शेवर का भी आ गया है
# [60.36s -> 61.42s]  जे ठाला
# [61.42s -> 64.94s]  इस आती का मेंटिल्स का चेक कभी भी टाइप पर नहीं आता
# [64.94s -> 67.58s]  तिक बेलो फोन करा अकवन करा

# %%
# !pip install insanely-fast-whisper
# Out:
# Collecting insanely-fast-whisper
#   Downloading insanely_fast_whisper-0.0.15-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from insanely-fast-whisper) (4.52.4)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (from insanely-fast-whisper) (1.7.0)
# Collecting pyannote-audio>=3.1.0 (from insanely-fast-whisper)
#   Downloading pyannote.audio-3.3.2-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: setuptools>=68.2.2 in /usr/local/lib/python3.11/dist-packages (from insanely-fast-whisper) (75.2.0)
# Requirement already satisfied: rich>=13.7.0 in /usr/local/lib/python3.11/dist-packages (from insanely-fast-whisper) (13.9.4)
# Collecting asteroid-filterbanks>=0.4 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading asteroid_filterbanks-0.4.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pyannote-audio>=3.1.0->insanely-fast-whisper) (0.8.1)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from pyannote-audio>=3.1.0->insanely-fast-whisper) (0.32.4)
# Collecting lightning>=2.0.1 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading lightning-2.5.1.post0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: omegaconf<3.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from pyannote-audio>=3.1.0->insanely-fast-whisper) (2.3.0)
# Collecting pyannote.core>=5.0.0 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading pyannote.core-5.0.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting pyannote.database>=5.0.1 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading pyannote.database-5.1.3-py3-none-any.whl.metadata (1.1 kB)
# Collecting pyannote.metrics>=3.2 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading pyannote.metrics-3.2.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting pyannote.pipeline>=3.0.1 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading pyannote.pipeline-3.0.1-py3-none-any.whl.metadata (897 bytes)
# Collecting pytorch-metric-learning>=2.1.0 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading pytorch_metric_learning-2.8.1-py3-none-any.whl.metadata (18 kB)
# Collecting semver>=3.0.0 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from pyannote-audio>=3.1.0->insanely-fast-whisper) (0.13.1)
# Collecting speechbrain>=1.0.0 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading speechbrain-1.0.3-py3-none-any.whl.metadata (24 kB)
# Collecting tensorboardX>=2.6 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pyannote-audio>=3.1.0->insanely-fast-whisper) (2.6.0+cu124)
# Collecting torch-audiomentations>=0.11.0 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading torch_audiomentations-0.12.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torchaudio>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from pyannote-audio>=3.1.0->insanely-fast-whisper) (2.6.0+cu124)
# Collecting torchmetrics>=0.11.0 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading torchmetrics-1.7.3-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.7.0->insanely-fast-whisper) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.7.0->insanely-fast-whisper) (2.19.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate->insanely-fast-whisper) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate->insanely-fast-whisper) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate->insanely-fast-whisper) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate->insanely-fast-whisper) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate->insanely-fast-whisper) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers->insanely-fast-whisper) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->insanely-fast-whisper) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers->insanely-fast-whisper) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->insanely-fast-whisper) (0.21.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers->insanely-fast-whisper) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from asteroid-filterbanks>=0.4->pyannote-audio>=3.1.0->insanely-fast-whisper) (4.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.1.2)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting pytorch-lightning (from lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.0->insanely-fast-whisper) (0.1.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf<3.0,>=2.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (4.9.3)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.11/dist-packages (from pyannote.core>=5.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (2.4.0)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.11/dist-packages (from pyannote.core>=5.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.15.3)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.11/dist-packages (from pyannote.database>=5.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (2.2.2)
# Requirement already satisfied: typer>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from pyannote.database>=5.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (0.16.0)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.11/dist-packages (from pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.6.1)
# Collecting docopt>=0.6.2 (from pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.11/dist-packages (from pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (0.9.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.10.0)
# Requirement already satisfied: sympy>=1.1 in /usr/local/lib/python3.11/dist-packages (from pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.13.1)
# Collecting optuna>=3.1 (from pyannote.pipeline>=3.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.17.1)
# Collecting hyperpyyaml (from speechbrain>=1.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading HyperPyYAML-1.2.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from speechbrain>=1.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.5.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from speechbrain>=1.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (0.2.0)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.11/dist-packages (from tensorboardX>=2.6->pyannote-audio>=3.1.0->insanely-fast-whisper) (5.29.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.1->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.3.0)
# Collecting julius<0.3,>=0.2.3 (from torch-audiomentations>=0.11.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading julius-0.2.7.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting torch-pitch-shift>=1.2.2 (from torch-audiomentations>=0.11.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading torch_pitch_shift-1.2.5-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->insanely-fast-whisper) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->insanely-fast-whisper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->insanely-fast-whisper) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->insanely-fast-whisper) (2025.4.26)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (2.22)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.11.15)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (2.9.0.post0)
# Collecting alembic>=1.5.0 (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading alembic-1.16.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (2.0.41)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pyannote.database>=5.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pyannote.database>=5.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.17.1->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.6.0)
# Collecting primePy>=1.3 (from torch-pitch-shift>=1.2.2->torch-audiomentations>=0.11.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading primePy-1.3-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.12.1->pyannote.database>=5.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.12.1->pyannote.database>=5.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.5.4)
# Collecting ruamel.yaml>=0.17.28 (from hyperpyyaml->speechbrain>=1.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading ruamel.yaml-0.18.14-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.20.0)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.1.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.17.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain>=1.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.2.2)
# Downloading insanely_fast_whisper-0.0.15-py3-none-any.whl (16 kB)
# Downloading pyannote.audio-3.3.2-py2.py3-none-any.whl (898 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 19.4 MB/s eta 0:00:00
# Downloading asteroid_filterbanks-0.4.0-py3-none-any.whl (29 kB)
# Downloading lightning-2.5.1.post0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 56.6 MB/s eta 0:00:00
# Downloading pyannote.core-5.0.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 5.5 MB/s eta 0:00:00
# Downloading pyannote.database-5.1.3-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 4.4 MB/s eta 0:00:00
# Downloading pyannote.metrics-3.2.1-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 4.7 MB/s eta 0:00:00
# Downloading pyannote.pipeline-3.0.1-py3-none-any.whl (31 kB)
# Downloading pytorch_metric_learning-2.8.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 kB 11.8 MB/s eta 0:00:00
# Downloading semver-3.0.4-py3-none-any.whl (17 kB)
# Downloading speechbrain-1.0.3-py3-none-any.whl (864 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 864.1/864.1 kB 52.8 MB/s eta 0:00:00
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 115.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.3 MB/s eta 0:00:00
# Downloading torch_audiomentations-0.12.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 4.5 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.3-py3-none-any.whl (962 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 962.6/962.6 kB 60.0 MB/s eta 0:00:00
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 34.9 MB/s eta 0:00:00
# Downloading torch_pitch_shift-1.2.5-py3-none-any.whl (5.0 kB)
# Downloading HyperPyYAML-1.2.2-py3-none-any.whl (16 kB)
# Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 58.0 MB/s eta 0:00:00
# Downloading alembic-1.16.1-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 22.5 MB/s eta 0:00:00
# Downloading primePy-1.3-py3-none-any.whl (4.0 kB)
# Downloading ruamel.yaml-0.18.14-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 kB 10.0 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (739 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 46.3 MB/s eta 0:00:00
# Building wheels for collected packages: docopt, julius
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=7a66ffbf2367084c2b15f1a37ea67c5e2fc56e24c8129f30beca83cfc8fed5d9
#   Stored in directory: /root/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
#   Building wheel for julius (setup.py) ... done
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21870 sha256=f8941f4c78f79303966bdde0dddad23ef77ec35b4aedfbae30e74de03a110db5
#   Stored in directory: /root/.cache/pip/wheels/16/15/d4/edd724cefe78050a6ba3344b8b0c6672db829a799dbb9f81ff
# Successfully built docopt julius
# Installing collected packages: primePy, docopt, tensorboardX, semver, ruamel.yaml.clib, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, colorlog, ruamel.yaml, pyannote.core, nvidia-cusparse-cu12, nvidia-cudnn-cu12, alembic, optuna, nvidia-cusolver-cu12, hyperpyyaml, pyannote.database, torchmetrics, pytorch-metric-learning, pyannote.pipeline, pyannote.metrics, julius, asteroid-filterbanks, torch-pitch-shift, speechbrain, pytorch-lightning, torch-audiomentations, lightning, pyannote-audio, insanely-fast-whisper
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed alembic-1.16.1 asteroid-filterbanks-0.4.0 colorlog-6.9.0 docopt-0.6.2 hyperpyyaml-1.2.2 insanely-fast-whisper-0.0.15 julius-0.2.7 lightning-2.5.1.post0 lightning-utilities-0.14.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 optuna-4.4.0 primePy-1.3 pyannote-audio-3.3.2 pyannote.core-5.0.0 pyannote.database-5.1.3 pyannote.metrics-3.2.1 pyannote.pipeline-3.0.1 pytorch-lightning-2.5.1.post0 pytorch-metric-learning-2.8.1 ruamel.yaml-0.18.14 ruamel.yaml.clib-0.2.12 semver-3.0.4 speechbrain-1.0.3 tensorboardX-2.6.4 torch-audiomentations-0.12.0 torch-pitch-shift-1.2.5 torchmetrics-1.7.3

# %%
# !pip install sentence-transformers scipy
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.3)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.52.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.32.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.14.0)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from scipy) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.4.26)

# %%
import threading
from faster_whisper import WhisperModel
from sentence_transformers import SentenceTransformer
from scipy.spatial.distance import cosine

# Initialize models
whisper_model = WhisperModel("large-v3", device="cuda", compute_type="float16")
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')  # Light and fast

# Transcription function
def transcribe_audio(audio_path, results, key):
    print(f"Transcribing {audio_path}...")
    segments, info = whisper_model.transcribe(audio_path, beam_size=5)
    transcript = " ".join([seg.text for seg in segments])
    results[key] = {
        "language": info.language,
        "language_probability": info.language_probability,
        "transcript": transcript
    }

# Input audio paths
audio_file_1 = "/content/tmkoc_part1.mp3"
audio_file_2 = "/content/tmkoc_part2.mp3"

# Store transcripts
transcriptions = {}

# Start transcription threads
t1 = threading.Thread(target=transcribe_audio, args=(audio_file_1, transcriptions, "file1"))
t2 = threading.Thread(target=transcribe_audio, args=(audio_file_2, transcriptions, "file2"))

t1.start()
t2.start()
t1.join()
t2.join()

# Extract transcripts
transcript1 = transcriptions["file1"]["transcript"]
print(transcript1)
transcript2 = transcriptions["file2"]["transcript"]
print(transcript2)
# Generate embeddings
embedding1 = embedding_model.encode(transcript1)
embedding2 = embedding_model.encode(transcript2)

# Calculate cosine similarity
similarity_score = 1 - cosine(embedding1, embedding2)

# Output
print("\n--- Cosine Similarity Results ---")
print(f"Transcript 1 Length: {len(transcript1)} characters")
print(f"Transcript 2 Length: {len(transcript2)} characters")
print(f"Cosine Similarity: {similarity_score:.4f}")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Transcribing /content/tmkoc_part1.mp3...
# Transcribing /content/tmkoc_part2.mp3...
#  उसके लिए थैंक यू  कभी-कभी आप पापड मिल देते हो  उसके लिए भी थैंक यू  दो मिलें पहले आपने मेरे चपड सीला के लेके आये थे  उसके लिए भी थैंक यू  आप मेरी सारी को भी हिस्ती कर देते हो  उसके लिए भी थैंक यू  और एक सिर्फ थैंक यू पूरा काई तलने पाती नहीं है  मैंने आपको जब चाय दी तो आपने मुझे थैंक यू बोला था  तो मेरे तो किसने थैंक यू बोलने बाखे  इसलिए अभी बोल रही हूँ थैंक यू  सोरी  परसो चाय में शक्कर जादा हो गई थी उसके लिए सोरी  खाने में नबक जादा हो गई था उसके लिए भी सोरी
#  पटन लगाना भूल गई थी उसके लिए फिर सॉरी  एक गड़े गड़े काई चलने बाद भी है  अहो पत्ती पत्ती मैं थैंक यू और सॉरी होता ही नहीं है  करलो  करलो सॉरी  थैंक यू  चाय पीछे बढ़ा नहीं हो जाएगी  पत्ती मैं थैंक यू और सॉरी होता ही नहीं हो जाएगी
#
# --- Cosine Similarity Results ---
# Transcript 1 Length: 462 characters
# Transcript 2 Length: 228 characters
# Cosine Similarity: 0.6604

# %%
import threading
import torch
import torchaudio
from transformers import WhisperProcessor, WhisperForConditionalGeneration
from sentence_transformers import SentenceTransformer
from scipy.spatial.distance import cosine

# Model setup
model_name = "bohraanuj23/whisper-small-hindi"
processor = WhisperProcessor.from_pretrained(model_name)
model = WhisperForConditionalGeneration.from_pretrained(model_name).to("cuda")
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')  # Same embedding model

# Transcription function using your fine-tuned Whisper
def transcribe_audio_custom(audio_path, results, key):
    print(f"Transcribing {audio_path} with fine-tuned Whisper...")

    # Load and resample audio
    waveform, sr = torchaudio.load(audio_path)
    waveform = torchaudio.functional.resample(waveform, orig_freq=sr, new_freq=16000).squeeze()

    # Chunk-based inference
    chunk_length_s = 30
    stride_length_s = 5
    input_stride = stride_length_s * 16000
    input_chunk = chunk_length_s * 16000

    full_transcript = ""
    start = 0

    while start < len(waveform):
        end = min(start + input_chunk, len(waveform))
        chunk = waveform[start:end]

        inputs = processor.feature_extractor(chunk, sampling_rate=16000, return_tensors="pt").input_features.to("cuda")

        with torch.no_grad():
            predicted_ids = model.generate(inputs)

        text = processor.tokenizer.batch_decode(predicted_ids, skip_special_tokens=True)[0]
        full_transcript += " " + text

        start += input_chunk - input_stride

    results[key] = {
        "transcript": full_transcript.strip()
    }

# Input audio files
audio_file_1 = "/content/tmkoc_part1.mp3"
audio_file_2 = "/content/tmkoc_part2.mp3"

# Store results
transcriptions = {}

# Threads
t1 = threading.Thread(target=transcribe_audio_custom, args=(audio_file_1, transcriptions, "file1"))
t2 = threading.Thread(target=transcribe_audio_custom, args=(audio_file_2, transcriptions, "file2"))

t1.start()
t2.start()
t1.join()
t2.join()

# Extract transcripts
transcript1 = transcriptions["file1"]["transcript"]
print("\nTranscript 1:\n", transcript1)

transcript2 = transcriptions["file2"]["transcript"]
print("\nTranscript 2:\n", transcript2)

# Embedding generation
embedding1 = embedding_model.encode(transcript1)
embedding2 = embedding_model.encode(transcript2)

# Cosine similarity
similarity_score = 1 - cosine(embedding1, embedding2)

# Output
print("\n--- Cosine Similarity Results ---")
print(f"Transcript 1 Length: {len(transcript1)} characters")
print(f"Transcript 2 Length: {len(transcript2)} characters")
print(f"Cosine Similarity: {similarity_score:.4f}")
# Out:
# Transcribing /content/tmkoc_part1.mp3 with fine-tuned Whisper...Transcribing /content/tmkoc_part2.mp3 with fine-tuned Whisper...
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Transcript 1:
#  उसके लिए थैंक्य। कभी-दवी आपड़ बेल देते हो, उसके लिए भी थैंक्य। दो मेले-मेले आपने मेरे चप्फल सिला के लेगा ऐसे, उसके लिए वी थैंक्य। आप वे दे सारी को भी स्थि कर देते हो, उसके लिए भी थैंक्य। और वे एकुपुरण काई तलग वी है? मैं ने अपको चाय दी तो अपने मुझे थैंक्यो पोला पाता, तो मेरे तो कित प्रते तैंक्यो पोल पके। इसलिए अभी पोल रीव, तैंक्यो! सड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़ड़� फॉरीः परसौद चायवेश शक्कर जाता होगे थी उसके लिए सॉरीः खाले में नपूर साथा होगे थी उसके लिए सॉरीः
#
# Transcript 2:
#  पुटर लगर पुल के थी उसके पी सॉरी। जेटालाः इस साति का मेंटिनस का चे कभी भी नायपड़ ने आता दिग्राला फोंग करा फूढ़ करा
#
# --- Cosine Similarity Results ---
# Transcript 1 Length: 476 characters
# Transcript 2 Length: 112 characters
# Cosine Similarity: 0.5129
